# %%
#pip install notebook

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
data = pd.DataFrame({
    'Name': ['Nikhil', 'Ravi'],
    'Marks': [88, 92]
})

data
# Out:
#      Name  Marks
# 0  Nikhil     88
# 1    Ravi     92

# %%
data = pd.read_csv(r"C:\Users\nikhi\Downloads\data_jobs.csv")

# %%
data
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
data.job_title
# Out:
# 0         Senior Clinical Data Engineer / Principal Clin...
# 1                                              Data Analyst
# 2         Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                    Data Engineer- Sr Jobs
#                                 ...
# 785736                                      DevOps Engineer
# 785737                                     CRM Data Analyst
# 785738                       Commercial Analyst - Start Now
# 785739    Principal Associate, Data Engineer (Remote-Eli...
# 785740                                   AWS System Analyst
# Name: job_title, Length: 785741, dtype: object

# %%
data.job_country
# Out:
# 0         United States
# 1                Mexico
# 2               Germany
# 3         United States
# 4                 Sudan
#               ...
# 785736        Singapore
# 785737          Germany
# 785738         Malaysia
# 785739            Sudan
# 785740            India
# Name: job_country, Length: 785741, dtype: object

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# PANDAS: INSPECTING

# %%
data.head(10)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
# 5         Data Engineer                                  GCP Data Engineer
# 6  Senior Data Engineer                  Senior Data Engineer  - GCP Cloud
# 7         Data Engineer                                      Data Engineer
# 8      Business Analyst           Technology & Operations Business Analyst
# 9        Data Scientist                                  Data Scientist II
#
#                    job_location             job_via         job_schedule_type  \
# ...

# %%
data.tail(10)
# Out:
#              job_title_short  \
# 785731         Data Engineer
# 785732         Data Engineer
# 785733     Software Engineer
# 785734      Business Analyst
# 785735  Senior Data Engineer
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 785731                                      Data Engineer
# 785732                              Data Engineer (f/m/d)
# 785733                                    DevOps Engineer
# 785734                                  PreSales Engineer
# 785735                               Senior Data Engineer
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# 785739  Principal Associate, Data Engineer (Remote-Eli...
# ...

# %%
data['job_title_short'].head(10)
# Out:
# 0    Senior Data Engineer
# 1            Data Analyst
# 2           Data Engineer
# 3           Data Engineer
# 4           Data Engineer
# 5           Data Engineer
# 6    Senior Data Engineer
# 7           Data Engineer
# 8        Business Analyst
# 9          Data Scientist
# Name: job_title_short, dtype: object

# %%
data[['job_title_short']]
# Out:
#              job_title_short
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
# [785741 rows x 1 columns]

# %%
data[['job_title_short','job_location']].head(10)
# Out:
#         job_title_short                  job_location
# 0  Senior Data Engineer                 Watertown, CT
# 1          Data Analyst  Guadalajara, Jalisco, Mexico
# 2         Data Engineer               Berlin, Germany
# 3         Data Engineer               San Antonio, TX
# 4         Data Engineer                Washington, DC
# 5         Data Engineer                      Anywhere
# 6  Senior Data Engineer                  Dearborn, MI
# 7         Data Engineer                      Anywhere
# 8      Business Analyst           Copenhagen, Denmark
# 9        Data Scientist                      Anywhere

# %%
data.iloc[90]
# Out:
# job_title_short                                             Data Scientist
# job_title                                                   Data Scientist
# job_location                                                     Australia
# job_via                                                via BeBee Australia
# job_schedule_type                                                Full-time
# job_work_from_home                                                   False
# search_location                                                  Australia
# job_posted_date                                        2023-11-25 13:12:03
# job_no_degree_mention                                                False
# job_health_insurance                                                 False
# job_country                                                      Australia
# salary_rate                                                            NaN
# ...

# %%
data.iloc[90:100, 0:3]
# Out:
#          job_title_short                                          job_title  \
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...
#
#                   job_location
# 90                   Australia
# 91               Temuco, Chile
# 92                    Anywhere
# ...

# %%
data[['job_title_short','job_title']].iloc[90:100]    #iloc = integer_location It is used to select rows and columns by their position number (index), not by name.
# Out:
#          job_title_short                                          job_title
# 90        Data Scientist                                     Data Scientist
# 91        Data Scientist                                     Data Scientist
# 92         Data Engineer            Remote - Data Engineer - Permanent - W2
# 93          Data Analyst       IT Finance / TBM Data Analyst - Remote | WFH
# 94         Data Engineer                   Data Engineer - Cloud Operations
# 95         Data Engineer                                      Data Engineer
# 96         Data Engineer                                      Data Engineer
# 97          Data Analyst  Systems & Data Analyst - Exploitation, Missing...
# 98  Senior Data Engineer                         Senior Data Engineer (AWS)
# 99         Data Engineer  Senior/Staff Data Engineer – Apache Spark (Jav...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
data.job_title_short.unique()
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
data.job_title_short == 'Data Analyst'
# Out:
# 0         False
# 1          True
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737     True
# 785738    False
# 785739    False
# 785740    False
# Name: job_title_short, Length: 785741, dtype: bool

# %%
data[data.job_title_short == 'Data Analyst']
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
data[(data.job_title_short == 'Data Analyst') & (data.salary_year_avg > 100000)]
# Out:
#        job_title_short                                      job_title  \
# 410       Data Analyst    IT Business Lead Data Analyst - VP - Hybrid
# 1555      Data Analyst                  Data Analyst/Engineer (M/F/D)
# 1681      Data Analyst                                   Data Analyst
# 1684      Data Analyst                       Data Analyst - Data17829
# 1867      Data Analyst  Data Integration Analyst (West Coast/Chicago)
# ...                ...                                            ...
# 783588    Data Analyst                         Data Analytics Manager
# 783866    Data Analyst                Lead Credit Bureau Data Analyst
# 784033    Data Analyst                       Recruitment Data Analyst
# 785187    Data Analyst                                   Data Analyst
# 785515    Data Analyst                                   Data Analyst
#
#                        job_location               job_via job_schedule_type  \
# ...

# %%
data.salary_year_avg.notna()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 785736    False
# 785737    False
# 785738    False
# 785739    False
# 785740    False
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
data.salary_year_avg.isna()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 785736    True
# 785737    True
# 785738    True
# 785739    True
# 785740    True
# Name: salary_year_avg, Length: 785741, dtype: bool

# %%
data[(data.job_title_short == 'Data Analyst') & (data.salary_year_avg.notna())]
# Out:
#        job_title_short                                    job_title  \
# 109       Data Analyst        Senior Supply Chain Analytics Analyst
# 180       Data Analyst                             Data Analyst III
# 410       Data Analyst  IT Business Lead Data Analyst - VP - Hybrid
# 988       Data Analyst                        DATA ANALYST (ONSITE)
# 1413      Data Analyst                          Junior BI Developer
# ...                ...                                          ...
# 784033    Data Analyst                     Recruitment Data Analyst
# 784423    Data Analyst                           Sales Data Analyst
# 784882    Data Analyst         Merchandising Analyst (Data Analyst)
# 785187    Data Analyst                                 Data Analyst
# 785515    Data Analyst                                 Data Analyst
#
#                        job_location                job_via job_schedule_type  \
# ...

# %%
data[(data.job_title_short == 'Data Analyst') & (data.salary_year_avg.isna())]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %% [markdown]
# PANDAS:CLEANING

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
type(data.job_posted_date[0])
# Out:
# str

# %%
data['job_posted_date'] = pd.to_datetime(data.job_posted_date)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.job_posted_date.dt.month
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
data['job_posted_month'] = data.job_posted_date.dt.month

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.sort_values('job_posted_date')
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
data.sort_values(by = 'job_posted_date', inplace = True)

# %%
data
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
data.drop(labels = 'salary_hour_avg',axis = 1)
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 351830              Data Engineer
# 362129              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 351830                                      Data engineer
# 362129                                      Data engineer
# ...

# %%
data.info()  #as we can see here even after removing the salary hour average column it is still in out data set for permanent remove it we need to do:
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
data.drop(labels = 'salary_hour_avg',axis = 1, inplace = True)  #with inplace = true now we removed the column permanent from our mainframe data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
data.dropna(subset=['salary_year_avg'], inplace = True)

# %% [markdown]
# data.info()

# %% [markdown]
# PANDAS : ANALYZING

# %%
data.describe()
# Out:
#                      job_posted_date  salary_year_avg  job_posted_month
# count                          22003     22003.000000      22003.000000
# mean   2023-06-13 01:01:01.813889024    123286.274072          5.886288
# min              2023-01-01 00:02:56     15000.000000          1.000000
# 25%       2023-03-17 14:04:49.500000     90000.000000          3.000000
# 50%              2023-06-11 09:03:27    115000.000000          6.000000
# 75%              2023-08-26 00:41:15    150000.000000          8.000000
# max              2023-12-31 23:40:32    960000.000000         12.000000
# std                              NaN     48312.449482          3.296650

# %%
data['salary_year_avg'].min()
# Out:
# np.float64(15000.0)

# %%
data['salary_year_avg'].median()
# Out:
# np.float64(115000.0)

# %%
min_salary = data['salary_year_avg'].idxmin()

# %%
data['job_title_short'].unique()
# Out:
# array(['Data Scientist', 'Data Engineer', 'Business Analyst',
#        'Data Analyst', 'Senior Data Engineer', 'Senior Data Scientist',
#        'Senior Data Analyst', 'Software Engineer',
#        'Machine Learning Engineer', 'Cloud Engineer'], dtype=object)

# %%
data['job_title_short'].value_counts()
# Out:
# job_title_short
# Data Scientist               5922
# Data Analyst                 5451
# Data Engineer                4500
# Senior Data Scientist        1690
# Senior Data Engineer         1591
# Senior Data Analyst          1131
# Business Analyst              610
# Machine Learning Engineer     576
# Software Engineer             467
# Cloud Engineer                 65
# Name: count, dtype: int64

# %%
data.groupby('job_title_short')['salary_year_avg'].min()
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
data.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
data.groupby(['job_title_short','job_country'])['salary_year_avg'].median()
# Out:
# job_title_short    job_country
# Business Analyst   Argentina                71100.0
#                    Australia                70000.0
#                    Bangladesh               16500.0
#                    Belgium                  89100.0
#                    Bulgaria                 71925.0
#                                              ...
# Software Engineer  Ukraine                  54000.0
#                    United Arab Emirates     79200.0
#                    United Kingdom           89100.0
#                    United States           130000.0
#                    Vietnam                  53600.0
# Name: salary_year_avg, Length: 598, dtype: float64

# %%
data.groupby('job_title_short')['salary_year_avg'].median()
# Out:
# job_title_short
# Business Analyst              85000.0
# Cloud Engineer                90000.0
# Data Analyst                  90000.0
# Data Engineer                125000.0
# Data Scientist               127500.0
# Machine Learning Engineer    106415.0
# Senior Data Analyst          111175.0
# Senior Data Engineer         147500.0
# Senior Data Scientist        155500.0
# Software Engineer             99150.0
# Name: salary_year_avg, dtype: float64

# %%
data.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median'])
# Out:
#                                min       max    median
# job_title_short
# Business Analyst           16500.0  387460.0   85000.0
# Cloud Engineer             42000.0  280000.0   90000.0
# Data Analyst               25000.0  650000.0   90000.0
# Data Engineer              15000.0  525000.0  125000.0
# Data Scientist             27000.0  960000.0  127500.0
# Machine Learning Engineer  30000.0  325000.0  106415.0
# Senior Data Analyst        30000.0  425000.0  111175.0
# Senior Data Engineer       35000.0  425000.0  147500.0
# Senior Data Scientist      45000.0  890000.0  155500.0
# Software Engineer          28000.0  375000.0   99150.0

# %% [markdown]
# PANDAS: EXERCISE....

# %%
data['job_country'].value_counts().head(20)
# Out:
# job_country
# United States     15766
# Sudan              1623
# India               582
# Canada              463
# United Kingdom      287
# Germany             257
# France              237
# Poland              200
# Spain               144
# Portugal            131
# Mexico              111
# Israel              103
# Singapore            98
# South Africa         92
# Netherlands          87
# Greece               82
# Australia            74
# Colombia             69
# Philippines          68
# South Korea          63
# Name: count, dtype: int64

# %%
 us_jobs = data[data['job_country'] == "United States"]

# %%
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
# now performing GROUPBY() Agreggation to perform mean median..etc

# %%
us_jobs = us_jobs[us_jobs['salary_year_avg'].notna()]

# %%
us_jobs
# Out:
#               job_title_short  \
# 108883         Data Scientist
# 365786       Business Analyst
# 366073           Data Analyst
# 108099         Data Scientist
# 78139           Data Engineer
# ...                       ...
# 679         Software Engineer
# 3448     Senior Data Engineer
# 186163  Senior Data Scientist
# 421728           Data Analyst
# 313161         Data Scientist
#
#                                                 job_title      job_location  \
# 108883                                     Data Scientist     Calabasas, CA
# 365786                     Hospitality Operations Analyst          Anywhere
# 366073                        Data Analytics Professional       Atlanta, GA
# 108099                       Lead Data Scientist (Hybrid)    Burnsville, MN
# 78139                   Data Engineer - Revenue Platforms        Boston, NY
# ...                                                   ...               ...
# ...

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median','count'])
# Out:
#                                min       max    median  count
# job_title_short
# Business Analyst           35000.0  387460.0   90000.0    431
# Cloud Engineer             42000.0  221844.0  116100.0     20
# Data Analyst               25000.0  375000.0   90000.0   4350
# Data Engineer              23496.0  525000.0  125000.0   2915
# Data Scientist             30000.0  960000.0  130000.0   4553
# Machine Learning Engineer  44408.5  315000.0  150000.0    128
# Senior Data Analyst        35360.0  425000.0  110000.0    913
# Senior Data Engineer       45000.0  375000.0  150000.0   1058
# Senior Data Scientist      55000.0  475000.0  155000.0   1241
# Software Engineer          48982.0  375000.0  130000.0    157

# %%
us_jobs.groupby('job_title_short')['salary_year_avg'].agg(['min','max','median','count']).sort_values(by = 'median', ascending = False)
# Out:
#                                min       max    median  count
# job_title_short
# Senior Data Scientist      55000.0  475000.0  155000.0   1241
# Machine Learning Engineer  44408.5  315000.0  150000.0    128
# Senior Data Engineer       45000.0  375000.0  150000.0   1058
# Data Scientist             30000.0  960000.0  130000.0   4553
# Software Engineer          48982.0  375000.0  130000.0    157
# Data Engineer              23496.0  525000.0  125000.0   2915
# Cloud Engineer             42000.0  221844.0  116100.0     20
# Senior Data Analyst        35360.0  425000.0  110000.0    913
# Business Analyst           35000.0  387460.0   90000.0    431
# Data Analyst               25000.0  375000.0   90000.0   4350
