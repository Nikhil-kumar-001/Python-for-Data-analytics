# %% [markdown]
# PANDAS: index management

# %%
# importing libraries

import pandas as pd
import matplotlib.pyplot as plt

#reading the csv file
data = pd.read_csv(r"C:\Users\nikhi\Downloads\data_jobs.csv")

# data cleanup
data['job_posted_date'] = pd.to_datetime(data['job_posted_date'])

# %%
data.sample(5)
# Out:
#             job_title_short                                     job_title  \
# 686708         Data Analyst                   Compliance Data Analyst III
# 284449       Data Scientist                 Data Scientist | Johannesburg
# 687472         Data Analyst      Analista de Datos / Data Analyst (h/m/x)
# 481805       Data Scientist  Principal Statistical Analyst/Data Scientist
# 671517  Senior Data Analyst            Senior Data Analyst (Data Modeler)
#
#                       job_location                        job_via  \
# 686708             San Antonio, TX                   via LinkedIn
# 284449  Johannesburg, South Africa  via SimplyHired, South Africa
# 687472               Madrid, Spain                   via LinkedIn
# 481805              Brook Park, OH                  via KSNT Jobs
# 671517                    Anywhere                   via LinkedIn
#
#        job_schedule_type  job_work_from_home          search_location  \
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=785741, step=1)

# %% [markdown]
# MAIN THREE METHODS TO COVER UNDER INDEX MANAGEMENT:
#
# 1 - data.reset_idex()
#
# 2 - data.set_index()
#
# 3 - data.sort_index()

# %%
# reset_index

df_usa = data[data['job_country'] == 'United States']

# %%
df_usa.head(10)

#as we can see in the results that we got the results of the based on usa
# but when we are looking at the job_index column the values are not in the series because we slice the part of main data to the new data
# accotding to out need and filter we have applied to make the job_index correct we use the reset_index()
# Out:
#                 job_title_short  \
# job_index
# 0          Senior Data Engineer
# 3                 Data Engineer
# 5                 Data Engineer
# 6          Senior Data Engineer
# 9                Data Scientist
# 11                Data Engineer
# 13         Senior Data Engineer
# 17               Data Scientist
# 26                Data Engineer
# 27                Data Engineer
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# 11                                             Data Engineer
# 13                                      Senior Data Engineer
# 17                                    Data Science Team Lead
# ...

# %%
# reset_index()

df_usa.reset_index(inplace=True)

df_usa
# Out:
#          index  job_index       job_title_short  \
# 0            0          0  Senior Data Engineer
# 1            1          3         Data Engineer
# 2            2          5         Data Engineer
# 3            3          6  Senior Data Engineer
# 4            4          9        Data Scientist
# ...        ...        ...                   ...
# 206287  206287     785673        Data Scientist
# 206288  206288     785685          Data Analyst
# 206289  206289     785692        Data Scientist
# 206290  206290     785703          Data Analyst
# 206291  206291     785705          Data Analyst
#
#                                                 job_title      job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...     Watertown, CT
# 1       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...   San Antonio, TX
# 2                                       GCP Data Engineer          Anywhere
# 3                       Senior Data Engineer  - GCP Cloud      Dearborn, MI
# ...

# %%
# set_index()

df_usa.set_index('job_index', inplace = True)
df_usa
# Out:
#             index       job_title_short  \
# job_index
# 0               0  Senior Data Engineer
# 3               1         Data Engineer
# 5               2         Data Engineer
# 6               3  Senior Data Engineer
# 9               4        Data Scientist
# ...           ...                   ...
# 785673     206287        Data Scientist
# 785685     206288          Data Analyst
# 785692     206289        Data Scientist
# 785703     206290          Data Analyst
# 785705     206291          Data Analyst
#
#                                                    job_title  \
# job_index
# 0          Senior Clinical Data Engineer / Principal Clin...
# 3          LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 5                                          GCP Data Engineer
# 6                          Senior Data Engineer  - GCP Cloud
# 9                                          Data Scientist II
# ...                                                      ...
# ...
