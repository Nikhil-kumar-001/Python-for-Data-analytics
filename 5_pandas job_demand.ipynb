# %% [markdown]
# # Exercise: Analyzing Data Science Job Demand

# %%
# importing libraries

import pandas as pd
import matplotlib.pyplot as plt

#reading the csv file
data = pd.read_csv(r"C:\Users\nikhi\Downloads\data_jobs.csv")

# data cleanup
data['job_posted_date'] = pd.to_datetime(data['job_posted_date'])

# %%
df_India = data[data['job_country'] == 'India'].copy()

# %%
df_India
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
df_India['job_posted_month'] = df_India['job_posted_date'].dt.strftime('%B')

df_India
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
df_india_pivot = df_India.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_india_pivot.reset_index(inplace=True)
df_india_pivot['month_no']=pd.to_datetime(df_india_pivot['job_posted_month'],format='%B').dt.month

df_india_pivot.sort_values('month_no', inplace=True)
df_india_pivot.set_index('job_posted_month', inplace=True)
df_india_pivot.drop(columns='month_no', inplace=True)

# %%
df_india_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df_india_pivot.plot(kind = 'line')
df_india_
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_3 = df_India['job_title_short'].value_counts().head(3)
top_3 = top_3.index.tolist()

# %%
df_india_pivot[top_3].plot(kind='line')

plt.title = ('Monthly job posting for top data jobs in India')
plt.xlabel = ('2023')
plt.ylabel = ('Job Count')
plt.legend()
plt.show()

# %% [markdown]
# Pandas: Merge Data frame

# %%
# in here we are merging another dataset in the comparision for example in this case we have a similar field with us is software development now we want to compare software jobs with our data jobs:
# This is out another csv file which contains the information about software job sector by which we will compare the data jobs

# df_US_software_pivot = pd.read_csv(r"C:\Users\nikhi\Downloads\software_jobs.csv", index_col='job_posted_month')
# df_US_software_pivot

# %%
# df_merged = df_india_pivot.merge(df_US_software_pivot, on='job_posted_month')

# %%
# top_5 = (
#     df_merged
#     .sum()
#     .sort_values(ascending = False)
#     . head()
#     .index
#     .to_list()
        
# )

# top_5
